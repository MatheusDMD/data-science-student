# %%
# %matplotlib inline
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy.random as rnd
from scipy.stats import ttest_ind
import math
import random

print("Esperamos trabalhar no diretório")
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\mathe_000\Desktop\INSPER\2015-2\Ciência dos Dados\Projeto 3

# %%
dados = pd.read_excel('Coal Consumption per capita.xls.xlsx')
dados
# Out:
#     Coal Consumption per person (tonnes oil equivalent)      1965      1966  \
# 0                                             Abkhazia        NaN       NaN
# 1                                          Afghanistan        NaN       NaN
# 2                                Akrotiri and Dhekelia        NaN       NaN
# 3                                              Albania        NaN       NaN
# 4                                              Algeria   0.005871  0.005560
# 5                                       American Samoa        NaN       NaN
# 6                                              Andorra        NaN       NaN
# 7                                               Angola        NaN       NaN
# 8                                             Anguilla        NaN       NaN
# 9                                  Antigua and Barbuda        NaN       NaN
# 10                                           Argentina   0.039244  0.039475
# ...
